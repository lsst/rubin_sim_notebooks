# %%
from rubin_sim.skybrightness_pre import SkyModelPre
import healpy as hp
import matplotlib.pylab as plt
# %matplotlib inline
import numpy as np

# %%
sm = SkyModelPre()

# %%
mags = sm.returnMags(59561.0486)

# %%
hp.mollview(mags['r'])

# %%
hp.mollview(sm.sb['r'][30])

# %%
sm.loaded_range
# Out:
# array([59561.03819444, 59566.35763888])

# %%
sm.mjds[30]
# Out:
# 59561.32986110987

# %%
mags = sm.returnMags(59562.3298)
hp.mollview(mags['r'])

# %%
mags = sm.returnMags(59562.5298)
hp.mollview(mags['r'])
# Out:
# /Users/yoachim/git_repos/rubin_sim/rubin_sim/skybrightness_pre/SkyModelPre.py:253: UserWarning: Requested MJD between sunrise and sunset, returning closest maps
#   warnings.warn(

# %%
mags = sm.returnMags(60218.4)
hp.mollview(mags['r'])
