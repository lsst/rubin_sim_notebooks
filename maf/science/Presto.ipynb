# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import healpy as hp

import rubin_sim.maf as maf
import rubin_sim.utils as rsUtils
from rubin_sim.data import get_baseline

# %%
baseline_file = get_baseline()
opsim = os.path.basename(baseline_file).replace('.db','')

# %%
slicer = maf.generate_presto_pop_slicer(skyregion='extragalactic')
metric = maf.PrestoColorKNePopMetric(skyregion='extragalactic')
summaryMetrics = [maf.MedianMetric(), maf.SumMetric()]
bundle = maf.MetricBundle(metric, slicer, None, run_name=opsim, summary_metrics=summaryMetrics)

# %%
outDir = 'test_presto'
bdict = {'presto': bundle}
g = maf.MetricBundleGroup(bdict, baseline_file, outDir)

# %%
g.run_all()
g.plot_all(closefigs=False)
# Out:
# /Users/yoachim/git_repos/rubin_sim/rubin_sim/maf/plots/plot_handler.py:587: UserWarning: Cannot plot object metric values with this plotter.
#   warnings.warn(
# /Users/yoachim/git_repos/rubin_sim/rubin_sim/maf/utils/maf_utils.py:148: UserWarning: Optimal bin calculation tried to make inf bins, returning 200
#   warnings.warn(
# /Users/yoachim/git_repos/rubin_sim/rubin_sim/maf/utils/maf_utils.py:148: UserWarning: Optimal bin calculation tried to make inf bins, returning 200
#   warnings.warn(
# /Users/yoachim/git_repos/rubin_sim/rubin_sim/maf/utils/maf_utils.py:148: UserWarning: Optimal bin calculation tried to make inf bins, returning 200
#   warnings.warn(

# %%
for key in g.bundle_dict:
    print(key, g.bundle_dict[key].summary_values)
# Out:
# presto {}
# KNePopMetric_presto_color_detect {'Median': 0.0, 'Sum': 450.0}
# KNePopMetric_score_p {'Median': 0.0, 'Sum': 240.47905117008284}
# KNePopMetric_score_s {'Median': 0.0, 'Sum': 190.0}

# %%
baseline_file = 'presto_gap4.0_mix_v2.0_10yrs.db'
opsim = os.path.basename(baseline_file).replace('.db','')

# %%
slicer = maf.generate_presto_pop_slicer(skyregion='extragalactic')
metric = maf.PrestoColorKNePopMetric(skyregion='extragalactic')
summaryMetrics = [maf.MedianMetric(), maf.SumMetric()]
bundle = maf.MetricBundle(metric, slicer, None, run_name=opsim, summary_metrics=summaryMetrics)

outDir = 'test_presto'
bdict = {'presto': bundle}
g = maf.MetricBundleGroup(bdict, baseline_file, outDir)

g.run_all()
g.plot_all(closefigs=False)
# Out:
# /Users/yoachim/git_repos/rubin_sim/rubin_sim/maf/plots/plot_handler.py:587: UserWarning: Cannot plot object metric values with this plotter.
#   warnings.warn(
# /Users/yoachim/git_repos/rubin_sim/rubin_sim/maf/utils/maf_utils.py:148: UserWarning: Optimal bin calculation tried to make inf bins, returning 200
#   warnings.warn(
# /Users/yoachim/git_repos/rubin_sim/rubin_sim/maf/utils/maf_utils.py:148: UserWarning: Optimal bin calculation tried to make inf bins, returning 200
#   warnings.warn(
# /Users/yoachim/git_repos/rubin_sim/rubin_sim/maf/utils/maf_utils.py:148: UserWarning: Optimal bin calculation tried to make inf bins, returning 200
#   warnings.warn(

# %%
for key in g.bundle_dict:
    print(key, g.bundle_dict[key].summary_values)
# Out:
# presto {}
# KNePopMetric_presto_color_detect {'Median': 0.0, 'Sum': 448.0}
# KNePopMetric_score_p {'Median': 0.0, 'Sum': 302.8071493206854}
# KNePopMetric_score_s {'Median': 0.0, 'Sum': 271.0}
